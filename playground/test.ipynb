# %%
# %run /Workspace/Users/syedsalahuddin1512000@gmail.com/api_lakehouse_data_pipeline/02.utils/01.logger

# %%
logger = get_logger("test")
def hello():
  logger.info("func started...")
  logger.info("hello world")
  logger.info("func ended.....")

# %%
hello()
